# %%
from preprocessing import MarkdownPreprocessor

# %%
mdprocessor = MarkdownPreprocessor('sagemaker_documentation')

# %%
chunks = mdprocessor.load_all_markdown()

# %%
chunks
# Out:
# [DocumentChunk(id='e15d963d-c86b-45b1-aee4-21330b636055', text='The configuration for the cluster of resources used to run the processing job\\.', raw_text='The configuration for the cluster of resources used to run the processing job\\.', source='aws-properties-sagemaker-dataqualityjobdefinition-clusterconfig.md', metadata={'title': 'aws-properties-sagemaker-dataqualityjobdefinition-clusterconfig'}),
#  DocumentChunk(id='e216d6cc-1d9e-4ab2-acf7-64cb91222e01', text='To declare this entity in your AWS CloudFormation template, use the following syntax:', raw_text='To declare this entity in your AWS CloudFormation template, use the following syntax:', source='aws-properties-sagemaker-dataqualityjobdefinition-clusterconfig.md', metadata={'title': 'aws-properties-sagemaker-dataqualityjobdefinition-clusterconfig', 'section': 'aws-properties-sagemaker-dataqualityjobdefinition-clusterconfig-syntax'}),
# ...
